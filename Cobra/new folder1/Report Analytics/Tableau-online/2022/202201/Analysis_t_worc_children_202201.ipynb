# %%
import pandas as pd
import numpy as np
import os

# %%
#children = adult = pd.read_excel('S://TANF Reports//Reports Analytics//202112//202112-t_worc_children-20220215_1356.xlsx')
children = adult = pd.read_excel('S://TANF Reports//!TANF Federal Reports//202201//WORC//Version4//202201-t_worc_children-20220504_0900.xlsx')

# %%
children['reporting_month'] = pd.to_datetime(children['reporting_month'].
                                             apply(lambda x: f"{x}01").
                                             astype(str), infer_datetime_format=True)

children['dob'] = pd.to_datetime(children['dob'].astype(str), infer_datetime_format=True)

children['age'] = np.floor((children['reporting_month'] - children['dob'])/np.timedelta64(1,'Y'))

# %%
children.shape
# Out:
# (2163, 26)

# %%
children['parent_minor_child'].value_counts()
# Out:
# Not parent with minor child in the family                                                        2162
# Yes, a parent with a minor child in the family, but not used in two-parent participation rate       1
# Name: parent_minor_child, dtype: int64

# %%
children.groupby(children['age']).agg({'parent_minor_child':'value_counts'}).rename({'parent_minor_child':'count'}, axis='columns').T
# Out:
# age                                                     0.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                     98
#
# age                                                     1.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                     99
#
# age                                                     2.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    134
#
# age                                                     3.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    134
#
# age                                                     4.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    150
#
# age                                                     5.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    126
#
# age                                                     6.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    124
#
# age                                                     7.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    116
#
# age                                                     8.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    126
#
# age                                                     9.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    135
#
# age                                                     10.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    118
#
# age                                                     11.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    105
#
# age                                                     12.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    133
#
# age                                                     13.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    141
#
# age                                                     14.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    135
#
# age                                                     15.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    113
#
# age                                                     16.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    100
#
# age                                                     17.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                     75
#
# age
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               1

# %%
k = children.loc[children['parent_minor_child']=="Yes, a parent with a minor child in the family, but not used in two-parent participation rate",('case_number','age','parent_minor_child')]
k = pd.DataFrame(k)

l = children.loc[children['parent_minor_child']=="Yes, a parent with a minor child in the family and used in two-parent participation rate",('case_number','age','parent_minor_child')]
l = pd.DataFrame(l)

# Append dataframes one below the other using concat
df1 = pd.concat([k,l],ignore_index=True)
df1
# Out:
#    case_number   age                                 parent_minor_child
# 0      9004467  17.0  Yes, a parent with a minor child in the family...

# %%
cn = df1['case_number'].nunique()
print(cn) #number of unique cases
print(df1.shape) #total number of parent with minor child instances
# Out:
# 1
# (1, 3)

# %%
children.groupby(['family_affiliation','age']).agg({'parent_minor_child':'value_counts'},axis='columns').rename({'parent_minor_child':'count'},axis='columns')#.reset_index()
# Out:
#                                                                                                             count
# family_affiliation                                 age  parent_minor_child
# Member of the eligible family receiving assistance 0.0  Not parent with minor child in the family              92
#                                                    1.0  Not parent with minor child in the family              94
#                                                    2.0  Not parent with minor child in the family             130
#                                                    3.0  Not parent with minor child in the family             127
#                                                    4.0  Not parent with minor child in the family             146
#                                                    5.0  Not parent with minor child in the family             123
#                                                    6.0  Not parent with minor child in the family             120
#                                                    7.0  Not parent with minor child in the family             113
#                                                    8.0  Not parent with minor child in the family             119
#                                                    9.0  Not parent with minor child in the family             131
#                                                    10.0 Not parent with minor child in the family             116
#                                                    11.0 Not parent with minor child in the family             103
#                                                    12.0 Not parent with minor child in the family             125
#                                                    13.0 Not parent with minor child in the family             136
#                                                    14.0 Not parent with minor child in the family             131
#                                                    15.0 Not parent with minor child in the family             109
#                                                    16.0 Not parent with minor child in the family              96
#                                                    17.0 Not parent with minor child in the family              74
#                                                         Yes, a parent with a minor child in the family,...      1
# Person whose income or resources are considered... 0.0  Not parent with minor child in the family               6
#                                                    1.0  Not parent with minor child in the family               5
#                                                    2.0  Not parent with minor child in the family               4
#                                                    3.0  Not parent with minor child in the family               7
#                                                    4.0  Not parent with minor child in the family               4
#                                                    5.0  Not parent with minor child in the family               3
#                                                    6.0  Not parent with minor child in the family               4
#                                                    7.0  Not parent with minor child in the family               3
#                                                    8.0  Not parent with minor child in the family               7
#                                                    9.0  Not parent with minor child in the family               4
#                                                    10.0 Not parent with minor child in the family               2
#                                                    11.0 Not parent with minor child in the family               2
#                                                    12.0 Not parent with minor child in the family               8
#                                                    13.0 Not parent with minor child in the family               5
#                                                    14.0 Not parent with minor child in the family               4
#                                                    15.0 Not parent with minor child in the family               4
#                                                    16.0 Not parent with minor child in the family               4
#                                                    17.0 Not parent with minor child in the family               1

# %%
children['age'].describe()
# Out:
# count    2163.000000
# mean        8.330559
# std         4.968199
# min         0.000000
# 25%         4.000000
# 50%         8.000000
# 75%        13.000000
# max        17.000000
# Name: age, dtype: float64

# %%
children.shape
# Out:
# (2163, 26)

# %%
os.chdir('S://TANF Reports//!TANF Federal Reports//202201//WORC//Version4')

from pandas import ExcelWriter

file_name = 'ParentWithMinorChild.xlsx'

writer = pd.ExcelWriter(file_name)
df1.to_excel(writer, sheet_name = '202109', index=False)
writer.save()
writer.close()


"""
import openpyxl
writer = pd.ExcelWriter(file_name, engine = 'openpyxl')

if os.path.exists(file_name):
    book = openpyxl.load_workbook(file_name)
    writer.book = book
    
df1.to_excel(writer, sheet_name = '202103', index=False)
writer.save()
writer.close()
"""
# Out:
# C:\Users\nnagaraj\AppData\Roaming\Python\Python39\site-packages\xlsxwriter\workbook.py:338: UserWarning: Calling close() on already closed file.
#   warn("Calling close() on already closed file.")
# "\nimport openpyxl\nwriter = pd.ExcelWriter(file_name, engine = 'openpyxl')\n\nif os.path.exists(file_name):\n    book = openpyxl.load_workbook(file_name)\n    writer.book = book\n    \ndf1.to_excel(writer, sheet_name = '202103', index=False)\nwriter.save()\nwriter.close()\n"
