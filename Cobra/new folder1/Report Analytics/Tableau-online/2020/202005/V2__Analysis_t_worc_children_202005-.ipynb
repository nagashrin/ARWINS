# %%
import pandas as pd
import numpy as np
import os

# %%
children = adult = pd.read_excel('H://Current_Working_Folder//Reports Analytics//202005//202005-t_worc_children-20200717_1053.xlsx')

# %%
children['reporting_month'] = pd.to_datetime(children['reporting_month'].
                                             apply(lambda x: f"{x}01").
                                             astype(str), infer_datetime_format=True)

children['dob'] = pd.to_datetime(children['dob'].astype(str), infer_datetime_format=True)

children['age'] = np.floor((children['reporting_month'] - children['dob'])/np.timedelta64(1,'Y'))

# %%
children.shape
# Out:
# (4140, 26)

# %%
children['parent_minor_child'].value_counts()
# Out:
# Not parent with minor child in the family                                                        4132
# Yes, a parent with a minor child in the family, but not used in two-parent participation rate       8
# Name: parent_minor_child, dtype: int64

# %%
children.groupby(children['age']).agg({'parent_minor_child':'value_counts'}).rename({'parent_minor_child':'count'}, axis='columns').T
# Out:
# age                                                     0.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    265
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               1
#
# age                                                     1.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    295
#
# age                                                     2.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    342
#
# age                                                     3.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    340
#
# age                                                     4.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    285
#
# age                                                     5.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    296
#
# age                                                     6.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    239
#
# age                                                     7.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    229
#
# age                                                     8.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    201
#
# age                                   ...                     \
# parent_minor_child                    ...
# count                                 ...
#
# age                                                     13.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    198
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               1
#
# age                                                     14.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    169
#
# age                                                     15.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    155
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               2
#
# age                                                     16.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    129
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               1
#
# age                                                     17.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    136
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               2
#
# age                                                     18.0
# parent_minor_child Not parent with minor child in the family
# count                                                      1
#
# [1 rows x 25 columns]

# %%
k = children.loc[children['parent_minor_child']=="Yes, a parent with a minor child in the family, but not used in two-parent participation rate",('case_number','age','parent_minor_child')]
k = pd.DataFrame(k)

l = children.loc[children['parent_minor_child']=="Yes, a parent with a minor child in the family and used in two-parent participation rate",('case_number','age','parent_minor_child')]
l = pd.DataFrame(l)

df1 = pd.concat([k,l],ignore_index=True)
df1
# Out:
#    case_number   age                                 parent_minor_child
# 0      6077810  17.0  Yes, a parent with a minor child in the family...
# 1      7289443  13.0  Yes, a parent with a minor child in the family...
# 2      7395576   0.0  Yes, a parent with a minor child in the family...
# 3      7863388  16.0  Yes, a parent with a minor child in the family...
# 4      9004467  15.0  Yes, a parent with a minor child in the family...
# 5      9015073  17.0  Yes, a parent with a minor child in the family...
# 6      9029763  11.0  Yes, a parent with a minor child in the family...
# 7      9060382  15.0  Yes, a parent with a minor child in the family...

# %%
cn = df1['case_number'].nunique()
print(cn) #number of unique cases
print(df1.shape) #total number of parent with minor child instances
# Out:
# 8
# (8, 3)

# %%
children.groupby(['family_affiliation','age']).agg({'parent_minor_child':'value_counts'},axis='columns').rename({'parent_minor_child':'count'},axis='columns')#.reset_index()
# Out:
#                                                                                                             count
# family_affiliation                                 age  parent_minor_child
# Member of the eligible family receiving assistance 0.0  Not parent with minor child in the family             238
#                                                         Yes, a parent with a minor child in the family,...      1
#                                                    1.0  Not parent with minor child in the family             277
#                                                    2.0  Not parent with minor child in the family             321
#                                                    3.0  Not parent with minor child in the family             323
#                                                    4.0  Not parent with minor child in the family             269
#                                                    5.0  Not parent with minor child in the family             281
#                                                    6.0  Not parent with minor child in the family             239
#                                                    7.0  Not parent with minor child in the family             229
#                                                    8.0  Not parent with minor child in the family             201
#                                                    9.0  Not parent with minor child in the family             196
#                                                    10.0 Not parent with minor child in the family             223
#                                                    11.0 Not parent with minor child in the family             220
#                                                         Yes, a parent with a minor child in the family,...      1
#                                                    12.0 Not parent with minor child in the family             213
#                                                    13.0 Not parent with minor child in the family             198
#                                                         Yes, a parent with a minor child in the family,...      1
#                                                    14.0 Not parent with minor child in the family             169
#                                                    15.0 Not parent with minor child in the family             155
#                                                         Yes, a parent with a minor child in the family,...      2
#                                                    16.0 Not parent with minor child in the family             129
#                                                         Yes, a parent with a minor child in the family,...      1
#                                                    17.0 Not parent with minor child in the family             136
#                                                         Yes, a parent with a minor child in the family,...      2
#                                                    18.0 Not parent with minor child in the family               1
# Person whose income or resources are considered... 0.0  Not parent with minor child in the family              27
#                                                    1.0  Not parent with minor child in the family              18
#                                                    2.0  Not parent with minor child in the family              21
#                                                    3.0  Not parent with minor child in the family              17
#                                                    4.0  Not parent with minor child in the family              16
#                                                    5.0  Not parent with minor child in the family              15

# %%
children['age'].describe()
# Out:
# count    4140.000000
# mean        7.245652
# std         4.992848
# min         0.000000
# 25%         3.000000
# 50%         7.000000
# 75%        11.000000
# max        18.000000
# Name: age, dtype: float64

# %%
children.shape
# Out:
# (4140, 26)

# %%
os.chdir('H://Current_Working_Folder//Reports Analytics//202005')
import openpyxl

file_name = 'ParentWithMinorChild.xlsx'
writer = pd.ExcelWriter(file_name, engine = 'openpyxl')

if os.path.exists(file_name):
    book = openpyxl.load_workbook(file_name)
    writer.book = book
    
df1.to_excel(writer, sheet_name = '202005_V2', index=False)
writer.save()
writer.close()
