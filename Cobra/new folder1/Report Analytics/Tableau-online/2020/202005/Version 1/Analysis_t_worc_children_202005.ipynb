# %%
import pandas as pd
import numpy as np
import os

# %%
children = adult = pd.read_excel('H://Current_Working_Folder//Reports Analytics//202005//202005-t_worc_children-20200715_1311.xlsx')

# %%
children['reporting_month'] = pd.to_datetime(children['reporting_month'].
                                             apply(lambda x: f"{x}01").
                                             astype(str), infer_datetime_format=True)

children['dob'] = pd.to_datetime(children['dob'].astype(str), infer_datetime_format=True)

children['age'] = np.floor((children['reporting_month'] - children['dob'])/np.timedelta64(1,'Y'))

# %%
children.shape
# Out:
# (4140, 26)

# %%
children['parent_minor_child'].value_counts()
# Out:
# Not parent with minor child in the family                                                        3845
# Yes, a parent with a minor child in the family and used in two-parent participation rate          173
# Yes, a parent with a minor child in the family, but not used in two-parent participation rate     122
# Name: parent_minor_child, dtype: int64

# %%
children.groupby(children['age']).agg({'parent_minor_child':'value_counts'}).rename({'parent_minor_child':'count'}, axis='columns').T
# Out:
# age                                                     0.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    219
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                              25
#
# age                                                                                                          \
# parent_minor_child Yes, a parent with a minor child in the family and used in two-parent participation rate
# count                                                              22
#
# age                                                     1.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    266
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                              21
#
# age                                                                                                          \
# parent_minor_child Yes, a parent with a minor child in the family and used in two-parent participation rate
# count                                                               8
#
# age                                                     2.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    306
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                              20
#
# age                                                                                                          \
# parent_minor_child Yes, a parent with a minor child in the family and used in two-parent participation rate
# count                                                              16
#
# age                                                     3.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    307
#
# age                                   ...                     \
# parent_minor_child                    ...
# count                                 ...
#
# age                                                     15.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    150
#
# age                                                                                                          \
# parent_minor_child Yes, a parent with a minor child in the family and used in two-parent participation rate
# count                                                               5
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               2
#
# age                                                     16.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    118
#
# age                                                                                                          \
# parent_minor_child Yes, a parent with a minor child in the family and used in two-parent participation rate
# count                                                               6
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               6
#
# age                                                     17.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    127
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               6
#
# age                                                                                                          \
# parent_minor_child Yes, a parent with a minor child in the family and used in two-parent participation rate
# count                                                               5
#
# age                                                     18.0
# parent_minor_child Not parent with minor child in the family
# count                                                      1
#
# [1 rows x 49 columns]

# %%
k = children.loc[children['parent_minor_child']=="Yes, a parent with a minor child in the family, but not used in two-parent participation rate",('case_number','age','parent_minor_child')]
k = pd.DataFrame(k)

l = children.loc[children['parent_minor_child']=="Yes, a parent with a minor child in the family and used in two-parent participation rate",('case_number','age','parent_minor_child')]
l = pd.DataFrame(l)

df1 = pd.concat([k,l],ignore_index=True)
df1
# Out:
#      case_number   age                                 parent_minor_child
# 0        7938369   1.0  Yes, a parent with a minor child in the family...
# 1        7304235   3.0  Yes, a parent with a minor child in the family...
# 2        7116282   1.0  Yes, a parent with a minor child in the family...
# 3        2920457   2.0  Yes, a parent with a minor child in the family...
# 4        3180139   4.0  Yes, a parent with a minor child in the family...
# 5         353388  16.0  Yes, a parent with a minor child in the family...
# 6         353388   2.0  Yes, a parent with a minor child in the family...
# 7        3039680   5.0  Yes, a parent with a minor child in the family...
# 8        3039680   2.0  Yes, a parent with a minor child in the family...
# 9        3052375   0.0  Yes, a parent with a minor child in the family...
# 10       3242359   5.0  Yes, a parent with a minor child in the family...
# 11       3242359   1.0  Yes, a parent with a minor child in the family...
# 12       6074356   2.0  Yes, a parent with a minor child in the family...
# 13       6385677  17.0  Yes, a parent with a minor child in the family...
# 14       6385677   0.0  Yes, a parent with a minor child in the family...
# 15       6676848   3.0  Yes, a parent with a minor child in the family...
# 16       6676848   2.0  Yes, a parent with a minor child in the family...
# 17       6717996   5.0  Yes, a parent with a minor child in the family...
# 18       6717996   3.0  Yes, a parent with a minor child in the family...
# 19       6799890   2.0  Yes, a parent with a minor child in the family...
# 20       6804553  16.0  Yes, a parent with a minor child in the family...
# 21       6804553   1.0  Yes, a parent with a minor child in the family...
# 22       6906099   4.0  Yes, a parent with a minor child in the family...
# 23       6958103   4.0  Yes, a parent with a minor child in the family...
# 24       7031991   0.0  Yes, a parent with a minor child in the family...
# 25       7032322   5.0  Yes, a parent with a minor child in the family...
# 26       7180599   0.0  Yes, a parent with a minor child in the family...
# 27       7317698   4.0  Yes, a parent with a minor child in the family...
# 28       7367149   5.0  Yes, a parent with a minor child in the family...
# 29       7612004  16.0  Yes, a parent with a minor child in the family...
# ..           ...   ...                                                ...
# 265      9052713   5.0  Yes, a parent with a minor child in the family...
# 266      9052713   3.0  Yes, a parent with a minor child in the family...
# 267      9052713   0.0  Yes, a parent with a minor child in the family...
# 268      9053835   3.0  Yes, a parent with a minor child in the family...
# 269      9053835   1.0  Yes, a parent with a minor child in the family...
# 270      8029232   3.0  Yes, a parent with a minor child in the family...
# 271      9001593   6.0  Yes, a parent with a minor child in the family...
# 272      9001593   4.0  Yes, a parent with a minor child in the family...
# 273      8006791  10.0  Yes, a parent with a minor child in the family...
# 274      8006791   5.0  Yes, a parent with a minor child in the family...
# 275      8006791   4.0  Yes, a parent with a minor child in the family...
# 276      8006791   2.0  Yes, a parent with a minor child in the family...
# 277      8006791   0.0  Yes, a parent with a minor child in the family...
# 278      7996222  13.0  Yes, a parent with a minor child in the family...
# 279      7914733  17.0  Yes, a parent with a minor child in the family...
# 280      7914733  14.0  Yes, a parent with a minor child in the family...
# 281      7914733  10.0  Yes, a parent with a minor child in the family...
# 282      7914733   5.0  Yes, a parent with a minor child in the family...
# 283      7914733   3.0  Yes, a parent with a minor child in the family...
# 284      7909276  14.0  Yes, a parent with a minor child in the family...
# 285      7909276  11.0  Yes, a parent with a minor child in the family...
# 286      7909276   8.0  Yes, a parent with a minor child in the family...
# 287      7909276   6.0  Yes, a parent with a minor child in the family...
# 288      7909276   4.0  Yes, a parent with a minor child in the family...
# 289      7617543  13.0  Yes, a parent with a minor child in the family...
# 290      7617543  11.0  Yes, a parent with a minor child in the family...
# 291      7617543   7.0  Yes, a parent with a minor child in the family...
# 292      7571896   9.0  Yes, a parent with a minor child in the family...
# 293      7571896   2.0  Yes, a parent with a minor child in the family...
# 294      3067985  16.0  Yes, a parent with a minor child in the family...
#
# [295 rows x 3 columns]

# %%
cn = df1['case_number'].nunique()
print(cn) #number of unique cases
print(df1.shape) #total number of parent with minor child instances
# Out:
# 159
# (295, 3)

# %%
children.groupby(['family_affiliation','age']).agg({'parent_minor_child':'value_counts'},axis='columns').rename({'parent_minor_child':'count'},axis='columns')#.reset_index()
# Out:
#                                                                                                             count
# family_affiliation                                 age  parent_minor_child
# Member of the eligible family receiving assistance 0.0  Not parent with minor child in the family             218
#                                                         Yes, a parent with a minor child in the family ...     18
#                                                         Yes, a parent with a minor child in the family,...      3
#                                                    1.0  Not parent with minor child in the family             265
#                                                         Yes, a parent with a minor child in the family ...      6
#                                                         Yes, a parent with a minor child in the family,...      6
#                                                    2.0  Not parent with minor child in the family             305
#                                                         Yes, a parent with a minor child in the family ...     14
#                                                         Yes, a parent with a minor child in the family,...      2
#                                                    3.0  Not parent with minor child in the family             306
#                                                         Yes, a parent with a minor child in the family ...     16
#                                                         Yes, a parent with a minor child in the family,...      1
#                                                    4.0  Not parent with minor child in the family             259
#                                                         Yes, a parent with a minor child in the family ...     10
#                                                    5.0  Not parent with minor child in the family             266
#                                                         Yes, a parent with a minor child in the family ...     15
#                                                    6.0  Not parent with minor child in the family             231
#                                                         Yes, a parent with a minor child in the family ...      8
#                                                    7.0  Not parent with minor child in the family             218
#                                                         Yes, a parent with a minor child in the family ...     11
#                                                    8.0  Not parent with minor child in the family             194
#                                                         Yes, a parent with a minor child in the family ...      7
#                                                    9.0  Not parent with minor child in the family             189
#                                                         Yes, a parent with a minor child in the family ...      7
#                                                    10.0 Not parent with minor child in the family             217
#                                                         Yes, a parent with a minor child in the family ...      6
#                                                    11.0 Not parent with minor child in the family             214
#                                                         Yes, a parent with a minor child in the family ...      6
#                                                         Yes, a parent with a minor child in the family,...      1
#                                                    12.0 Not parent with minor child in the family             209
# ...                                                                                                           ...
#                                                    14.0 Not parent with minor child in the family             163
#                                                         Yes, a parent with a minor child in the family ...      5
#                                                         Yes, a parent with a minor child in the family,...      1
#                                                    15.0 Not parent with minor child in the family             150
#                                                         Yes, a parent with a minor child in the family ...      5
#                                                         Yes, a parent with a minor child in the family,...      2
#                                                    16.0 Not parent with minor child in the family             118
#                                                         Yes, a parent with a minor child in the family ...      6
#                                                         Yes, a parent with a minor child in the family,...      6
#                                                    17.0 Not parent with minor child in the family             127
#                                                         Yes, a parent with a minor child in the family,...      6
#                                                         Yes, a parent with a minor child in the family ...      5
#                                                    18.0 Not parent with minor child in the family               1
# Person whose income or resources are considered... 0.0  Yes, a parent with a minor child in the family,...     22
#                                                         Yes, a parent with a minor child in the family ...      4
#                                                         Not parent with minor child in the family               1
#                                                    1.0  Yes, a parent with a minor child in the family,...     15
#                                                         Yes, a parent with a minor child in the family ...      2
#                                                         Not parent with minor child in the family               1
#                                                    2.0  Yes, a parent with a minor child in the family,...     18
#                                                         Yes, a parent with a minor child in the family ...      2
#                                                         Not parent with minor child in the family               1
#                                                    3.0  Yes, a parent with a minor child in the family,...     12
#                                                         Yes, a parent with a minor child in the family ...      4
#                                                         Not parent with minor child in the family               1
#                                                    4.0  Yes, a parent with a minor child in the family,...     13
#                                                         Yes, a parent with a minor child in the family ...      3
#                                                    5.0  Yes, a parent with a minor child in the family,...     13
#                                                         Not parent with minor child in the family               1
#                                                         Yes, a parent with a minor child in the family ...      1
#
# [64 rows x 1 columns]

# %%
children['age'].describe()
# Out:
# count    4140.000000
# mean        7.245652
# std         4.992848
# min         0.000000
# 25%         3.000000
# 50%         7.000000
# 75%        11.000000
# max        18.000000
# Name: age, dtype: float64

# %%
children.shape
# Out:
# (4140, 26)

# %%
os.chdir('H://Current_Working_Folder//Reports Analytics//202005')
import openpyxl

file_name = 'ParentWithMinorChild.xlsx'
writer = pd.ExcelWriter(file_name, engine = 'openpyxl')

if os.path.exists(file_name):
    book = openpyxl.load_workbook(file_name)
    writer.book = book
    
df1.to_excel(writer, sheet_name = '202005', index=False)
writer.save()
writer.close()
