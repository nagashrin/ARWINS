# %%
import pandas as pd
import numpy as np
import os

# %%
children = adult = pd.read_excel('H://Current_Working_Folder//Reports Analytics//202007//202007-t_worc_children-20200917_1610.xlsx')

# %%
children['reporting_month'] = pd.to_datetime(children['reporting_month'].
                                             apply(lambda x: f"{x}01").
                                             astype(str), infer_datetime_format=True)

children['dob'] = pd.to_datetime(children['dob'].astype(str), infer_datetime_format=True)

children['age'] = np.floor((children['reporting_month'] - children['dob'])/np.timedelta64(1,'Y'))

# %%
children.shape
# Out:
# (4073, 26)

# %%
children['parent_minor_child'].value_counts()
# Out:
# Not parent with minor child in the family                                                        3864
# Yes, a parent with a minor child in the family, but not used in two-parent participation rate     198
# Yes, a parent with a minor child in the family and used in two-parent participation rate           11
# Name: parent_minor_child, dtype: int64

# %%
children.groupby(children['age']).agg({'parent_minor_child':'value_counts'}).rename({'parent_minor_child':'count'}, axis='columns').T
# Out:
# age                                                                                                        -1.0   \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               2
#
# age                                                     0.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    211
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                              31
#
# age                                                                                                          \
# parent_minor_child Yes, a parent with a minor child in the family and used in two-parent participation rate
# count                                                               1
#
# age                                                     1.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    269
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                              40
#
# age                                                                                                          \
# parent_minor_child Yes, a parent with a minor child in the family and used in two-parent participation rate
# count                                                               2
#
# age                                                     2.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    298
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                              30
#
# age                                                                                                          \
# parent_minor_child Yes, a parent with a minor child in the family and used in two-parent participation rate
# count                                                               2
#
# age                                   ...                     \
# parent_minor_child                    ...
# count                                 ...
#
# age                                                     12.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    202
#
# age                                                     13.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    209
#
# age                                                     14.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    162
#
# age                                                     15.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    147
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               1
#
# age                                                     16.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    125
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               6
#
# age                                                     17.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    137
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               6
#
# age                                                     18.0
# parent_minor_child Not parent with minor child in the family
# count                                                      1
#
# [1 rows x 35 columns]

# %%
k = children.loc[children['parent_minor_child']=="Yes, a parent with a minor child in the family, but not used in two-parent participation rate",('case_number','age','parent_minor_child')]
k = pd.DataFrame(k)

l = children.loc[children['parent_minor_child']=="Yes, a parent with a minor child in the family and used in two-parent participation rate",('case_number','age','parent_minor_child')]
l = pd.DataFrame(l)

df1 = pd.concat([k,l],ignore_index=True)
df1
# Out:
#      case_number   age                                 parent_minor_child
# 0        7533724   0.0  Yes, a parent with a minor child in the family...
# 1        7815531   0.0  Yes, a parent with a minor child in the family...
# 2        9027187   0.0  Yes, a parent with a minor child in the family...
# 3        7304235   3.0  Yes, a parent with a minor child in the family...
# 4        2920457   3.0  Yes, a parent with a minor child in the family...
# 5         353388  16.0  Yes, a parent with a minor child in the family...
# 6         353388   3.0  Yes, a parent with a minor child in the family...
# 7        2347322   3.0  Yes, a parent with a minor child in the family...
# 8        2460483  16.0  Yes, a parent with a minor child in the family...
# 9        2460483   1.0  Yes, a parent with a minor child in the family...
# 10       2748653  16.0  Yes, a parent with a minor child in the family...
# 11       2748653   1.0  Yes, a parent with a minor child in the family...
# 12       2797474  17.0  Yes, a parent with a minor child in the family...
# 13       2797474   1.0  Yes, a parent with a minor child in the family...
# 14       2860290  15.0  Yes, a parent with a minor child in the family...
# 15       2860290   0.0  Yes, a parent with a minor child in the family...
# 16       2956135   1.0  Yes, a parent with a minor child in the family...
# 17       3052375   0.0  Yes, a parent with a minor child in the family...
# 18       3085963   5.0  Yes, a parent with a minor child in the family...
# 19       3157341   5.0  Yes, a parent with a minor child in the family...
# 20       3311546   2.0  Yes, a parent with a minor child in the family...
# 21       3311546   1.0  Yes, a parent with a minor child in the family...
# 22       3334823   5.0  Yes, a parent with a minor child in the family...
# 23       3336331   2.0  Yes, a parent with a minor child in the family...
# 24       4764687   3.0  Yes, a parent with a minor child in the family...
# 25       4764687   4.0  Yes, a parent with a minor child in the family...
# 26       5563152   1.0  Yes, a parent with a minor child in the family...
# 27       5817552   0.0  Yes, a parent with a minor child in the family...
# 28       7037262   1.0  Yes, a parent with a minor child in the family...
# 29       7044200   2.0  Yes, a parent with a minor child in the family...
# ..           ...   ...                                                ...
# 179      7997455   1.0  Yes, a parent with a minor child in the family...
# 180      8006287   4.0  Yes, a parent with a minor child in the family...
# 181      8006834   2.0  Yes, a parent with a minor child in the family...
# 182      8006889   3.0  Yes, a parent with a minor child in the family...
# 183      8007036   3.0  Yes, a parent with a minor child in the family...
# 184      8011750   4.0  Yes, a parent with a minor child in the family...
# 185      8017119   0.0  Yes, a parent with a minor child in the family...
# 186      8017313   4.0  Yes, a parent with a minor child in the family...
# 187      8018776   2.0  Yes, a parent with a minor child in the family...
# 188      8022149   4.0  Yes, a parent with a minor child in the family...
# 189      8022149   2.0  Yes, a parent with a minor child in the family...
# 190      8022149   1.0  Yes, a parent with a minor child in the family...
# 191      8030213   3.0  Yes, a parent with a minor child in the family...
# 192      8032679   0.0  Yes, a parent with a minor child in the family...
# 193      9001685   0.0  Yes, a parent with a minor child in the family...
# 194      9003941   0.0  Yes, a parent with a minor child in the family...
# 195      9004147   4.0  Yes, a parent with a minor child in the family...
# 196      9009372   5.0  Yes, a parent with a minor child in the family...
# 197      9009372   1.0  Yes, a parent with a minor child in the family...
# 198      7304235   3.0  Yes, a parent with a minor child in the family...
# 199      3085963   5.0  Yes, a parent with a minor child in the family...
# 200      7706825   5.0  Yes, a parent with a minor child in the family...
# 201      7706825   3.0  Yes, a parent with a minor child in the family...
# 202      7706825   1.0  Yes, a parent with a minor child in the family...
# 203      7706825   1.0  Yes, a parent with a minor child in the family...
# 204      7859291   0.0  Yes, a parent with a minor child in the family...
# 205      7859291   3.0  Yes, a parent with a minor child in the family...
# 206      7859291   2.0  Yes, a parent with a minor child in the family...
# 207      7865547   2.0  Yes, a parent with a minor child in the family...
# 208      6929995   3.0  Yes, a parent with a minor child in the family...
#
# [209 rows x 3 columns]

# %%
cn = df1['case_number'].nunique()
print(cn) #number of unique cases
print(df1.shape) #total number of parent with minor child instances
# Out:
# 143
# (209, 3)

# %%
children.groupby(['family_affiliation','age']).agg({'parent_minor_child':'value_counts'},axis='columns').rename({'parent_minor_child':'count'},axis='columns')#.reset_index()
# Out:
#                                                                                                              count
# family_affiliation                                 age   parent_minor_child
# Member of the eligible family receiving assistance  0.0  Not parent with minor child in the family             209
#                                                          Yes, a parent with a minor child in the family,...      1
#                                                     1.0  Not parent with minor child in the family             269
#                                                          Yes, a parent with a minor child in the family,...      7
#                                                     2.0  Not parent with minor child in the family             298
#                                                          Yes, a parent with a minor child in the family,...      1
#                                                     3.0  Not parent with minor child in the family             290
#                                                          Yes, a parent with a minor child in the family,...      2
#                                                     4.0  Not parent with minor child in the family             271
#                                                     5.0  Not parent with minor child in the family             236
#                                                     6.0  Not parent with minor child in the family             248
#                                                     7.0  Not parent with minor child in the family             217
#                                                     8.0  Not parent with minor child in the family             210
#                                                     9.0  Not parent with minor child in the family             198
#                                                     10.0 Not parent with minor child in the family             205
#                                                     11.0 Not parent with minor child in the family             227
#                                                          Yes, a parent with a minor child in the family,...      1
#                                                     12.0 Not parent with minor child in the family             202
#                                                     13.0 Not parent with minor child in the family             209
#                                                     14.0 Not parent with minor child in the family             162
#                                                     15.0 Not parent with minor child in the family             147
#                                                          Yes, a parent with a minor child in the family,...      1
#                                                     16.0 Not parent with minor child in the family             125
#                                                          Yes, a parent with a minor child in the family,...      6
#                                                     17.0 Not parent with minor child in the family             137
#                                                          Yes, a parent with a minor child in the family,...      6
#                                                     18.0 Not parent with minor child in the family               1
# Person whose income or resources are considered... -1.0  Yes, a parent with a minor child in the family,...      2
#                                                     0.0  Yes, a parent with a minor child in the family,...     30
#                                                          Not parent with minor child in the family               2
#                                                          Yes, a parent with a minor child in the family ...      1
#                                                     1.0  Yes, a parent with a minor child in the family,...     33
#                                                          Yes, a parent with a minor child in the family ...      2
#                                                     2.0  Yes, a parent with a minor child in the family,...     29
#                                                          Yes, a parent with a minor child in the family ...      2
#                                                     3.0  Yes, a parent with a minor child in the family,...     32
#                                                          Yes, a parent with a minor child in the family ...      4
#                                                          Not parent with minor child in the family               1
#                                                     4.0  Yes, a parent with a minor child in the family,...     25
#                                                     5.0  Yes, a parent with a minor child in the family,...     22
#                                                          Yes, a parent with a minor child in the family ...      2

# %%
children['age'].describe()
# Out:
# count    4073.000000
# mean        7.277437
# std         5.002320
# min        -1.000000
# 25%         3.000000
# 50%         7.000000
# 75%        11.000000
# max        18.000000
# Name: age, dtype: float64

# %%
children.shape
# Out:
# (4073, 26)

# %%
os.chdir('H://Current_Working_Folder//Reports Analytics//202007')
import openpyxl

file_name = 'ParentWithMinorChild.xlsx'
writer = pd.ExcelWriter(file_name, engine = 'openpyxl')

if os.path.exists(file_name):
    book = openpyxl.load_workbook(file_name)
    writer.book = book
    
df1.to_excel(writer, sheet_name = '202006', index=False)
writer.save()
writer.close()

# %%
children.columns
# Out:
# Index(['id', 'reporting_month', 'case_number', 'family_affiliation', 'dob',
#        'ssn', 'hispanic or latino', 'american indian or alaska native',
#        'asian', 'black or african american',
#        'native hawaiian or other pacific islander', 'white', 'gender',
#        'Receives Benefits Based on Federal Disability Status Under Non-Social Security Act Programs',
#        'Receives Supplemental Security Income Under Title XVI-SSI of the SocialSecurity Act:',
#        'relation_to_hoh', 'parent_minor_child', 'education_level',
#        'citizenship', 'Amount of unearned inocme_SSI',
#        'Amount of unearned income_Other unearned income', 'created_by',
#        'updated_by', 'created_at', 'updated_at', 'age'],
#       dtype='object')
