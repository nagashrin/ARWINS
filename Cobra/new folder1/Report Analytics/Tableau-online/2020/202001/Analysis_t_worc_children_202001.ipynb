# %%
import pandas as pd
import numpy as np
import os

# %%
children = adult = pd.read_excel('H://Current_Working_Folder//Reports Analytics//202001//202001-t_worc_children-20200512_1223.xlsx')

# %%
children['reporting_month'] = pd.to_datetime(children['reporting_month'].
                                             apply(lambda x: f"{x}01").
                                             astype(str), infer_datetime_format=True)

children['dob'] = pd.to_datetime(children['dob'].astype(str), infer_datetime_format=True)

children['age'] = np.floor((children['reporting_month'] - children['dob'])/np.timedelta64(1,'Y'))

# %%
children.shape
# Out:
# (4017, 26)

# %%
children['parent_minor_child'].value_counts()
# Out:
# Not parent with minor child in the family                                                        4014
# Yes, a parent with a minor child in the family, but not used in two-parent participation rate       3
# Name: parent_minor_child, dtype: int64

# %%
children.groupby(children['age']).agg({'parent_minor_child':'value_counts'}).rename({'parent_minor_child':'count'}, axis='columns').T
# Out:
# age                                                    -1.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                      1
#
# age                                                     0.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    258
#
# age                                                     1.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    326
#
# age                                                     2.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    344
#
# age                                                     3.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    331
#
# age                                                     4.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    253
#
# age                                                     5.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    282
#
# age                                                     6.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    233
#
# age                                                     7.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    217
#
# age                                                     8.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    205
#
# age                                                             ...                                               \
# parent_minor_child                                              ...
# count                                                           ...
#
# age                                                     10.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    202
#
# age                                                     11.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    213
#
# age                                                     12.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    211
#
# age                                                     13.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    180
#
# age                                                     14.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    164
#
# age                                                     15.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    153
#
# age                                                     16.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    122
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               1
#
# age                                                     17.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    135
#
# age
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               2
#
# [1 rows x 21 columns]

# %%
k = children.loc[children['parent_minor_child']=="Yes, a parent with a minor child in the family, but not used in two-parent participation rate",('case_number','age','parent_minor_child')]
k
# Out:
#       case_number   age                                 parent_minor_child
# 3945      2324395  17.0  Yes, a parent with a minor child in the family...
# 3986      6077810  17.0  Yes, a parent with a minor child in the family...
# 3987      7863388  16.0  Yes, a parent with a minor child in the family...

# %%
children.groupby(['family_affiliation','age']).agg({'parent_minor_child':'value_counts'},axis='columns').rename({'parent_minor_child':'count'},axis='columns')#.reset_index()
# Out:
#                                                                                                              count
# family_affiliation                                 age   parent_minor_child
# Member of the eligible family receiving assistance  0.0  Not parent with minor child in the family             224
#                                                          Yes, a parent with a minor child in the family,...      1
#                                                     1.0  Not parent with minor child in the family             282
#                                                          Yes, a parent with a minor child in the family,...      1
#                                                     2.0  Not parent with minor child in the family             310
#                                                          Yes, a parent with a minor child in the family,...      1
#                                                     3.0  Not parent with minor child in the family             303
#                                                     4.0  Not parent with minor child in the family             227
#                                                     5.0  Not parent with minor child in the family             267
#                                                     6.0  Not parent with minor child in the family             233
#                                                     7.0  Not parent with minor child in the family             217
#                                                     8.0  Not parent with minor child in the family             205
#                                                     9.0  Not parent with minor child in the family             184
#                                                     10.0 Not parent with minor child in the family             202
#                                                     11.0 Not parent with minor child in the family             213
#                                                     12.0 Not parent with minor child in the family             211
#                                                     13.0 Not parent with minor child in the family             180
#                                                     14.0 Not parent with minor child in the family             163
#                                                          Yes, a parent with a minor child in the family,...      1
#                                                     15.0 Not parent with minor child in the family             152
#                                                          Yes, a parent with a minor child in the family,...      1
#                                                     16.0 Not parent with minor child in the family             122
#                                                          Yes, a parent with a minor child in the family,...      1
#                                                     17.0 Not parent with minor child in the family             135
#                                                          Yes, a parent with a minor child in the family,...      2
# Person whose income or resources are considered... -1.0  Not parent with minor child in the family               1
#                                                     0.0  Not parent with minor child in the family              33
#                                                     1.0  Not parent with minor child in the family              43
#                                                     2.0  Not parent with minor child in the family              32
#                                                          Yes, a parent with a minor child in the family ...      1
#                                                     3.0  Not parent with minor child in the family              28
#                                                     4.0  Not parent with minor child in the family              26
#                                                     5.0  Not parent with minor child in the family              15

# %%
children['age'].describe()
# Out:
# count    4017.000000
# mean        7.160568
# std         5.021999
# min        -1.000000
# 25%         3.000000
# 50%         6.000000
# 75%        11.000000
# max        17.000000
# Name: age, dtype: float64

# %%
children.shape
# Out:
# (4017, 26)

# %%
os.chdir('H://Current_Working_Folder//Reports Analytics//202001')

writer = pd.ExcelWriter('ParentWithMinorChild1.xlsx')
k.to_excel(writer, sheet_name = '202001')
writer.save()

# %%
writer = pd.ExcelWriter('PythonExport.xlsx')
yourdf.to_excel(writer, sheet_name='Sheet5')
writer.save()

# DF TO CSV
yourdf.to_csv('PythonExport.csv', sep=',')
