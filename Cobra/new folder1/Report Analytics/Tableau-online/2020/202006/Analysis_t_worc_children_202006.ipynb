# %%
import pandas as pd
import numpy as np
import os

# %%
children = adult = pd.read_excel('H://Current_Working_Folder//Reports Analytics//202006//202006-t_worc_children-20200811_1123.xlsx')

# %%
children['reporting_month'] = pd.to_datetime(children['reporting_month'].
                                             apply(lambda x: f"{x}01").
                                             astype(str), infer_datetime_format=True)

children['dob'] = pd.to_datetime(children['dob'].astype(str), infer_datetime_format=True)

children['age'] = np.floor((children['reporting_month'] - children['dob'])/np.timedelta64(1,'Y'))

# %%
children.shape
# Out:
# (4116, 26)

# %%
children['parent_minor_child'].value_counts()
# Out:
# Not parent with minor child in the family                                                        4107
# Yes, a parent with a minor child in the family, but not used in two-parent participation rate       9
# Name: parent_minor_child, dtype: int64

# %%
children.groupby(children['age']).agg({'parent_minor_child':'value_counts'}).rename({'parent_minor_child':'count'}, axis='columns').T
# Out:
# age                                                    -1.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                      1
#
# age                                                     0.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    258
#
# age                                                     1.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    300
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               1
#
# age                                                     2.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    343
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               1
#
# age                                                     3.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    327
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               1
#
# age                                                     4.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    296
#
# age                                                     5.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    273
#
# age                                                             ...                                               \
# parent_minor_child                                              ...
# count                                                           ...
#
# age                                                     11.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    219
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               1
#
# age                                                     12.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    207
#
# age                                                     13.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    213
#
# age                                                     14.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    162
#
# age                                                     15.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    164
#
# age                                                     16.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    126
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               3
#
# age                                                     17.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    144
#
# age
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               2
#
# [1 rows x 25 columns]

# %%
k = children.loc[children['parent_minor_child']=="Yes, a parent with a minor child in the family, but not used in two-parent participation rate",('case_number','age','parent_minor_child')]
k = pd.DataFrame(k)

l = children.loc[children['parent_minor_child']=="Yes, a parent with a minor child in the family and used in two-parent participation rate",('case_number','age','parent_minor_child')]
l = pd.DataFrame(l)

df1 = pd.concat([k,l],ignore_index=True)
df1
# Out:
#    case_number   age                                 parent_minor_child
# 0      6077810  17.0  Yes, a parent with a minor child in the family...
# 1      7863388  16.0  Yes, a parent with a minor child in the family...
# 2      9004467  16.0  Yes, a parent with a minor child in the family...
# 3      9015073  17.0  Yes, a parent with a minor child in the family...
# 4      9029763  11.0  Yes, a parent with a minor child in the family...
# 5      9060382  16.0  Yes, a parent with a minor child in the family...
# 6      8013666   3.0  Yes, a parent with a minor child in the family...
# 7      8013666   2.0  Yes, a parent with a minor child in the family...
# 8      8001742   1.0  Yes, a parent with a minor child in the family...

# %%
cn = df1['case_number'].nunique()
print(cn) #number of unique cases
print(df1.shape) #total number of parent with minor child instances
# Out:
# 8
# (9, 3)

# %%
children.groupby(['family_affiliation','age']).agg({'parent_minor_child':'value_counts'},axis='columns').rename({'parent_minor_child':'count'},axis='columns')#.reset_index()
# Out:
#                                                                                                              count
# family_affiliation                                 age   parent_minor_child
# Member of the eligible family receiving assistance -1.0  Not parent with minor child in the family               1
#                                                     0.0  Not parent with minor child in the family             227
#                                                     1.0  Not parent with minor child in the family             281
#                                                     2.0  Not parent with minor child in the family             308
#                                                     3.0  Not parent with minor child in the family             308
#                                                     4.0  Not parent with minor child in the family             277
#                                                     5.0  Not parent with minor child in the family             245
#                                                     6.0  Not parent with minor child in the family             242
#                                                     7.0  Not parent with minor child in the family             218
#                                                     8.0  Not parent with minor child in the family             203
#                                                     9.0  Not parent with minor child in the family             195
#                                                     10.0 Not parent with minor child in the family             216
#                                                     11.0 Not parent with minor child in the family             219
#                                                          Yes, a parent with a minor child in the family,...      1
#                                                     12.0 Not parent with minor child in the family             207
#                                                     13.0 Not parent with minor child in the family             213
#                                                     14.0 Not parent with minor child in the family             162
#                                                     15.0 Not parent with minor child in the family             164
#                                                     16.0 Not parent with minor child in the family             126
#                                                          Yes, a parent with a minor child in the family,...      3
#                                                     17.0 Not parent with minor child in the family             144
#                                                          Yes, a parent with a minor child in the family,...      2
# Person whose income or resources are considered...  0.0  Not parent with minor child in the family              31
#                                                     1.0  Not parent with minor child in the family              19
#                                                          Yes, a parent with a minor child in the family,...      1
#                                                     2.0  Not parent with minor child in the family              35
#                                                          Yes, a parent with a minor child in the family,...      1
#                                                     3.0  Not parent with minor child in the family              19
#                                                          Yes, a parent with a minor child in the family,...      1
#                                                     4.0  Not parent with minor child in the family              19
#                                                     5.0  Not parent with minor child in the family              28

# %%
children['age'].describe()
# Out:
# count    4116.000000
# mean        7.284985
# std         5.023075
# min        -1.000000
# 25%         3.000000
# 50%         7.000000
# 75%        11.000000
# max        17.000000
# Name: age, dtype: float64

# %%
children.shape
# Out:
# (4116, 26)

# %%
os.chdir('H://Current_Working_Folder//Reports Analytics//202006')
import openpyxl

file_name = 'ParentWithMinorChild.xlsx'
writer = pd.ExcelWriter(file_name, engine = 'openpyxl')

if os.path.exists(file_name):
    book = openpyxl.load_workbook(file_name)
    writer.book = book
    
df1.to_excel(writer, sheet_name = '202006', index=False)
writer.save()
writer.close()
