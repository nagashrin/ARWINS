# %%
import pandas as pd
import numpy as np
import os

# %%
children = adult = pd.read_excel('H://Current_Working_Folder//Reports Analytics//202010//202010-t_worc_children-20201214_1144.xlsx')

# %%
children['reporting_month'] = pd.to_datetime(children['reporting_month'].
                                             apply(lambda x: f"{x}01").
                                             astype(str), infer_datetime_format=True)

children['dob'] = pd.to_datetime(children['dob'].astype(str), infer_datetime_format=True)

children['age'] = np.floor((children['reporting_month'] - children['dob'])/np.timedelta64(1,'Y'))

# %%
children.shape
# Out:
# (3559, 26)

# %%
children['parent_minor_child'].value_counts()
# Out:
# Not parent with minor child in the family                                                        3535
# Yes, a parent with a minor child in the family, but not used in two-parent participation rate      24
# Name: parent_minor_child, dtype: int64

# %%
children.groupby(children['age']).agg({'parent_minor_child':'value_counts'}).rename({'parent_minor_child':'count'}, axis='columns').T
# Out:
# age                                                    -1.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                      1
#
# age                                                     0.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    190
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               1
#
# age                                                     1.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    245
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               7
#
# age                                                     2.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    275
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               1
#
# age                                                     3.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    303
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               2
#
# age                                                     4.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    240
#
# age                                                             ...                                               \
# parent_minor_child                                              ...
# count                                                           ...
#
# age                                                                                                         11.0  \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               1
#
# age                                                     12.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    205
#
# age                                                     13.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    188
#
# age                                                     14.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    174
#
# age                                                     15.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    119
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               2
#
# age                                                     16.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    122
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               5
#
# age                                                     17.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    123
#
# age
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               5
#
# [1 rows x 27 columns]

# %%
k = children.loc[children['parent_minor_child']=="Yes, a parent with a minor child in the family, but not used in two-parent participation rate",('case_number','age','parent_minor_child')]
k = pd.DataFrame(k)

l = children.loc[children['parent_minor_child']=="Yes, a parent with a minor child in the family and used in two-parent participation rate",('case_number','age','parent_minor_child')]
l = pd.DataFrame(l)

df1 = pd.concat([k,l],ignore_index=True)
df1
# Out:
#     case_number   age                                 parent_minor_child
# 0        353388  16.0  Yes, a parent with a minor child in the family...
# 1        353388   3.0  Yes, a parent with a minor child in the family...
# 2       2460483   1.0  Yes, a parent with a minor child in the family...
# 3       2748653  17.0  Yes, a parent with a minor child in the family...
# 4       2748653   1.0  Yes, a parent with a minor child in the family...
# 5       2860290  15.0  Yes, a parent with a minor child in the family...
# 6       2860290   1.0  Yes, a parent with a minor child in the family...
# 7       7250637  15.0  Yes, a parent with a minor child in the family...
# 8       7250637   0.0  Yes, a parent with a minor child in the family...
# 9       7612004  17.0  Yes, a parent with a minor child in the family...
# 10      7612004   2.0  Yes, a parent with a minor child in the family...
# 11      6385677  17.0  Yes, a parent with a minor child in the family...
# 12      6385677   1.0  Yes, a parent with a minor child in the family...
# 13      6804553  16.0  Yes, a parent with a minor child in the family...
# 14      6804553   1.0  Yes, a parent with a minor child in the family...
# 15      9015073   3.0  Yes, a parent with a minor child in the family...
# 16      7863388  16.0  Yes, a parent with a minor child in the family...
# 17      9004467  16.0  Yes, a parent with a minor child in the family...
# 18      9015073  17.0  Yes, a parent with a minor child in the family...
# 19      9029763  11.0  Yes, a parent with a minor child in the family...
# 20      9060382  16.0  Yes, a parent with a minor child in the family...
# 21      9068090   1.0  Yes, a parent with a minor child in the family...
# 22      7985387  17.0  Yes, a parent with a minor child in the family...
# 23      7985387   1.0  Yes, a parent with a minor child in the family...

# %%
cn = df1['case_number'].nunique()
print(cn) #number of unique cases
print(df1.shape) #total number of parent with minor child instances
# Out:
# 15
# (24, 3)

# %%
children.groupby(['family_affiliation','age']).agg({'parent_minor_child':'value_counts'},axis='columns').rename({'parent_minor_child':'count'},axis='columns')#.reset_index()
# Out:
#                                                                                                              count
# family_affiliation                                 age   parent_minor_child
# Member of the eligible family receiving assistance -1.0  Not parent with minor child in the family               1
#                                                     0.0  Not parent with minor child in the family             168
#                                                          Yes, a parent with a minor child in the family,...      1
#                                                     1.0  Not parent with minor child in the family             227
#                                                          Yes, a parent with a minor child in the family,...      7
#                                                     2.0  Not parent with minor child in the family             246
#                                                          Yes, a parent with a minor child in the family,...      1
#                                                     3.0  Not parent with minor child in the family             273
#                                                          Yes, a parent with a minor child in the family,...      2
#                                                     4.0  Not parent with minor child in the family             219
#                                                     5.0  Not parent with minor child in the family             198
#                                                     6.0  Not parent with minor child in the family             211
#                                                     7.0  Not parent with minor child in the family             208
#                                                     8.0  Not parent with minor child in the family             176
#                                                     9.0  Not parent with minor child in the family             183
#                                                     10.0 Not parent with minor child in the family             175
#                                                     11.0 Not parent with minor child in the family             194
#                                                          Yes, a parent with a minor child in the family,...      1
#                                                     12.0 Not parent with minor child in the family             205
#                                                     13.0 Not parent with minor child in the family             188
#                                                     14.0 Not parent with minor child in the family             174
#                                                     15.0 Not parent with minor child in the family             119
#                                                          Yes, a parent with a minor child in the family,...      2
#                                                     16.0 Not parent with minor child in the family             122
#                                                          Yes, a parent with a minor child in the family,...      5
#                                                     17.0 Not parent with minor child in the family             123
#                                                          Yes, a parent with a minor child in the family,...      5
# Person whose income or resources are considered...  0.0  Not parent with minor child in the family              22
#                                                     1.0  Not parent with minor child in the family              18
#                                                     2.0  Not parent with minor child in the family              29
#                                                     3.0  Not parent with minor child in the family              30
#                                                     4.0  Not parent with minor child in the family              21
#                                                     5.0  Not parent with minor child in the family               5

# %%
children['age'].describe()
# Out:
# count    3559.000000
# mean        7.509975
# std         5.012222
# min        -1.000000
# 25%         3.000000
# 50%         7.000000
# 75%        12.000000
# max        17.000000
# Name: age, dtype: float64

# %%
children.shape
# Out:
# (3679, 26)

# %%
os.chdir('H://Current_Working_Folder//Reports Analytics//202010')
import openpyxl

file_name = 'ParentWithMinorChild.xlsx'
writer = pd.ExcelWriter(file_name, engine = 'openpyxl')

if os.path.exists(file_name):
    book = openpyxl.load_workbook(file_name)
    writer.book = book
    
df1.to_excel(writer, sheet_name = '202010', index=False)
writer.save()
writer.close()

# %%
children.columns
# Out:
# Index(['id', 'reporting_month', 'case_number', 'family_affiliation', 'dob',
#        'ssn', 'hispanic or latino', 'american indian or alaska native',
#        'asian', 'black or african american',
#        'native hawaiian or other pacific islander', 'white', 'gender',
#        'Receives Benefits Based on Federal Disability Status Under Non-Social Security Act Programs',
#        'Receives Supplemental Security Income Under Title XVI-SSI of the SocialSecurity Act:',
#        'relation_to_hoh', 'parent_minor_child', 'education_level',
#        'citizenship', 'Amount of unearned inocme_SSI',
#        'Amount of unearned income_Other unearned income', 'created_by',
#        'updated_by', 'created_at', 'updated_at', 'age'],
#       dtype='object')
