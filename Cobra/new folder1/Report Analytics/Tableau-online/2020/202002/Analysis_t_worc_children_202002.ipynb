# %%
import pandas as pd
import numpy as np
import os

# %%
children = adult = pd.read_excel('H://Current_Working_Folder//Reports Analytics//202002//202002-t_worc_children-20200512_1231.xlsx')

# %%
children['reporting_month'] = pd.to_datetime(children['reporting_month'].
                                             apply(lambda x: f"{x}01").
                                             astype(str), infer_datetime_format=True)

children['dob'] = pd.to_datetime(children['dob'].astype(str), infer_datetime_format=True)

children['age'] = np.floor((children['reporting_month'] - children['dob'])/np.timedelta64(1,'Y'))

# %%
children.shape
# Out:
# (4014, 26)

# %%
children['parent_minor_child'].value_counts()
# Out:
# Not parent with minor child in the family                                                        4011
# Yes, a parent with a minor child in the family, but not used in two-parent participation rate       3
# Name: parent_minor_child, dtype: int64

# %%
children.groupby(children['age']).agg({'parent_minor_child':'value_counts'}).rename({'parent_minor_child':'count'}, axis='columns').T
# Out:
# age                                                    -1.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                      1
#
# age                                                     0.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    255
#
# age                                                     1.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    320
#
# age                                                     2.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    338
#
# age                                                     3.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    334
#
# age                                                     4.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    247
#
# age                                                     5.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    293
#
# age                                                     6.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    227
#
# age                                                     7.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    219
#
# age                                                     8.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    199
#
# age                                                             ...                                               \
# parent_minor_child                                              ...
# count                                                           ...
#
# age                                                     10.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    207
#
# age                                                     11.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    212
#
# age                                                     12.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    212
#
# age                                                     13.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    180
#
# age                                                     14.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    163
#
# age                                                     15.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    150
#
# age                                                     16.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    124
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               1
#
# age                                                     17.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    140
#
# age
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               2
#
# [1 rows x 21 columns]

# %%
k = children.loc[children['parent_minor_child']=="Yes, a parent with a minor child in the family, but not used in two-parent participation rate",('case_number','age','parent_minor_child')]
k
# Out:
#       case_number   age                                 parent_minor_child
# 1271      6077810  17.0  Yes, a parent with a minor child in the family...
# 3953      2324395  17.0  Yes, a parent with a minor child in the family...
# 3954      7863388  16.0  Yes, a parent with a minor child in the family...

# %%
children.groupby(['family_affiliation','age']).agg({'parent_minor_child':'value_counts'},axis='columns').rename({'parent_minor_child':'count'},axis='columns')#.reset_index()
# Out:
#                                                                                                              count
# family_affiliation                                 age   parent_minor_child
# Member of the eligible family receiving assistance -1.0  Not parent with minor child in the family               1
#                                                     0.0  Not parent with minor child in the family             227
#                                                     1.0  Not parent with minor child in the family             293
#                                                     2.0  Not parent with minor child in the family             309
#                                                     3.0  Not parent with minor child in the family             307
#                                                     4.0  Not parent with minor child in the family             231
#                                                     5.0  Not parent with minor child in the family             269
#                                                     6.0  Not parent with minor child in the family             227
#                                                     7.0  Not parent with minor child in the family             219
#                                                     8.0  Not parent with minor child in the family             199
#                                                     9.0  Not parent with minor child in the family             190
#                                                     10.0 Not parent with minor child in the family             207
#                                                     11.0 Not parent with minor child in the family             212
#                                                     12.0 Not parent with minor child in the family             212
#                                                     13.0 Not parent with minor child in the family             180
#                                                     14.0 Not parent with minor child in the family             163
#                                                     15.0 Not parent with minor child in the family             150
#                                                     16.0 Not parent with minor child in the family             124
#                                                          Yes, a parent with a minor child in the family,...      1
#                                                     17.0 Not parent with minor child in the family             140
#                                                          Yes, a parent with a minor child in the family,...      2
# Person whose income or resources are considered...  0.0  Not parent with minor child in the family              28
#                                                     1.0  Not parent with minor child in the family              27
#                                                     2.0  Not parent with minor child in the family              29
#                                                     3.0  Not parent with minor child in the family              27
#                                                     4.0  Not parent with minor child in the family              16
#                                                     5.0  Not parent with minor child in the family              24

# %%
children['age'].describe()
# Out:
# count    4014.000000
# mean        7.194569
# std         5.022973
# min        -1.000000
# 25%         3.000000
# 50%         6.000000
# 75%        11.000000
# max        17.000000
# Name: age, dtype: float64

# %%
children.shape
# Out:
# (4014, 26)

# %%
os.chdir('H://Current_Working_Folder//Reports Analytics//202001')
import openpyxl

file_name = 'ParentWithMinorChild.xlsx'
writer = pd.ExcelWriter(file_name, engine = 'openpyxl')

if os.path.exists(file_name):
    book = openpyxl.load_workbook(file_name)
    writer.book = book
    
k.to_excel(writer, sheet_name = '202002', index=False)
writer.save()
writer.close()
