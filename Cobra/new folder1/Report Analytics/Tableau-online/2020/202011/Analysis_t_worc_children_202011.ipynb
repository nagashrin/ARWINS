# %%
import pandas as pd
import numpy as np
import os

# %%
children = adult = pd.read_excel('H://Current_Working_Folder//Reports Analytics//202011//202011-t_worc_children-20210212_1547.xlsx')

# %%
children['reporting_month'] = pd.to_datetime(children['reporting_month'].
                                             apply(lambda x: f"{x}01").
                                             astype(str), infer_datetime_format=True)

children['dob'] = pd.to_datetime(children['dob'].astype(str), infer_datetime_format=True)

children['age'] = np.floor((children['reporting_month'] - children['dob'])/np.timedelta64(1,'Y'))

# %%
children.shape
# Out:
# (3431, 26)

# %%
children['parent_minor_child'].value_counts()
# Out:
# Not parent with minor child in the family                                                        3425
# Yes, a parent with a minor child in the family, but not used in two-parent participation rate       6
# Name: parent_minor_child, dtype: int64

# %%
children.groupby(children['age']).agg({'parent_minor_child':'value_counts'}).rename({'parent_minor_child':'count'}, axis='columns').T
# Out:
# age                                                     0.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    170
#
# age                                                     1.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    268
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               1
#
# age                                                     2.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    257
#
# age                                                     3.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    280
#
# age                                                     4.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    239
#
# age                                                     5.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    212
#
# age                                                     6.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    197
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               1
#
# age                                                     7.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    190
#
# age                                                             ...                                               \
# parent_minor_child                                              ...
# count                                                           ...
#
# age                                                     10.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    171
#
# age                                                     11.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    190
#
# age                                                     12.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    204
#
# age                                                     13.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    190
#
# age                                                     14.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    155
#
# age                                                     15.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    130
#
# age                                                     16.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    117
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               2
#
# age                                                     17.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    113
#
# age
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               2
#
# [1 rows x 22 columns]

# %%
k = children.loc[children['parent_minor_child']=="Yes, a parent with a minor child in the family, but not used in two-parent participation rate",('case_number','age','parent_minor_child')]
k = pd.DataFrame(k)

l = children.loc[children['parent_minor_child']=="Yes, a parent with a minor child in the family and used in two-parent participation rate",('case_number','age','parent_minor_child')]
l = pd.DataFrame(l)

# Append dataframes one below the other using concat
df1 = pd.concat([k,l],ignore_index=True)
df1
# Out:
#    case_number   age                                 parent_minor_child
# 0      7897236   6.0  Yes, a parent with a minor child in the family...
# 1      9068090   1.0  Yes, a parent with a minor child in the family...
# 2      7863388  16.0  Yes, a parent with a minor child in the family...
# 3      9004467  16.0  Yes, a parent with a minor child in the family...
# 4      7612004  17.0  Yes, a parent with a minor child in the family...
# 5      9015073  17.0  Yes, a parent with a minor child in the family...

# %%
cn = df1['case_number'].nunique()
print(cn) #number of unique cases
print(df1.shape) #total number of parent with minor child instances
# Out:
# 6
# (6, 3)

# %%
children.groupby(['family_affiliation','age']).agg({'parent_minor_child':'value_counts'},axis='columns').rename({'parent_minor_child':'count'},axis='columns')#.reset_index()
# Out:
#                                                                                                             count
# family_affiliation                                 age  parent_minor_child
# Member of the eligible family receiving assistance 0.0  Not parent with minor child in the family             154
#                                                    1.0  Not parent with minor child in the family             236
#                                                         Yes, a parent with a minor child in the family,...      1
#                                                    2.0  Not parent with minor child in the family             230
#                                                    3.0  Not parent with minor child in the family             260
#                                                    4.0  Not parent with minor child in the family             217
#                                                    5.0  Not parent with minor child in the family             193
#                                                    6.0  Not parent with minor child in the family             197
#                                                         Yes, a parent with a minor child in the family,...      1
#                                                    7.0  Not parent with minor child in the family             190
#                                                    8.0  Not parent with minor child in the family             180
#                                                    9.0  Not parent with minor child in the family             162
#                                                    10.0 Not parent with minor child in the family             171
#                                                    11.0 Not parent with minor child in the family             190
#                                                    12.0 Not parent with minor child in the family             204
#                                                    13.0 Not parent with minor child in the family             190
#                                                    14.0 Not parent with minor child in the family             155
#                                                    15.0 Not parent with minor child in the family             130
#                                                    16.0 Not parent with minor child in the family             117
#                                                         Yes, a parent with a minor child in the family,...      2
#                                                    17.0 Not parent with minor child in the family             113
#                                                         Yes, a parent with a minor child in the family,...      2
# Person whose income or resources are considered... 0.0  Not parent with minor child in the family              16
#                                                    1.0  Not parent with minor child in the family              32
#                                                    2.0  Not parent with minor child in the family              27
#                                                    3.0  Not parent with minor child in the family              20
#                                                    4.0  Not parent with minor child in the family              22
#                                                    5.0  Not parent with minor child in the family              19

# %%
children['age'].describe()
# Out:
# count    3431.000000
# mean        7.505683
# std         4.996781
# min         0.000000
# 25%         3.000000
# 50%         7.000000
# 75%        12.000000
# max        17.000000
# Name: age, dtype: float64

# %%
children.shape
# Out:
# (3431, 26)

# %%
os.chdir('H://Current_Working_Folder//Reports Analytics//202011')
import openpyxl

file_name = 'ParentWithMinorChild.xlsx'
writer = pd.ExcelWriter(file_name, engine = 'openpyxl')

if os.path.exists(file_name):
    book = openpyxl.load_workbook(file_name)
    writer.book = book
    
df1.to_excel(writer, sheet_name = '202011', index=False)
writer.save()
writer.close()

# %%
children.columns
# Out:
# Index(['id', 'reporting_month', 'case_number', 'family_affiliation', 'dob',
#        'ssn', 'hispanic or latino', 'american indian or alaska native',
#        'asian', 'black or african american',
#        'native hawaiian or other pacific islander', 'white', 'gender',
#        'Receives Benefits Based on Federal Disability Status Under Non-Social Security Act Programs',
#        'Receives Supplemental Security Income Under Title XVI-SSI of the SocialSecurity Act:',
#        'relation_to_hoh', 'parent_minor_child', 'education_level',
#        'citizenship', 'Amount of unearned inocme_SSI',
#        'Amount of unearned income_Other unearned income', 'created_by',
#        'updated_by', 'created_at', 'updated_at', 'age'],
#       dtype='object')
