# %%
import pandas as pd
import numpy as np
import os

# %%
children = adult = pd.read_excel('H://Current_Working_Folder//Reports Analytics//202008//202008-t_worc_children-20201112_1524.xlsx')

# %%
children['reporting_month'] = pd.to_datetime(children['reporting_month'].
                                             apply(lambda x: f"{x}01").
                                             astype(str), infer_datetime_format=True)

children['dob'] = pd.to_datetime(children['dob'].astype(str), infer_datetime_format=True)

children['age'] = np.floor((children['reporting_month'] - children['dob'])/np.timedelta64(1,'Y'))

# %%
children.shape
# Out:
# (3892, 26)

# %%
children['parent_minor_child'].value_counts()
# Out:
# Not parent with minor child in the family                                                        3887
# Yes, a parent with a minor child in the family, but not used in two-parent participation rate       5
# Name: parent_minor_child, dtype: int64

# %%
children.groupby(children['age']).agg({'parent_minor_child':'value_counts'}).rename({'parent_minor_child':'count'}, axis='columns').T
# Out:
# age                                                    -1.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                      1
#
# age                                                     0.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    221
#
# age                                                     1.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    292
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               1
#
# age                                                     2.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    313
#
# age                                                     3.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    321
#
# age                                                     4.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    285
#
# age                                                     5.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    229
#
# age                                                     6.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    235
#
# age                                                     7.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    219
#
# age                                   ...                     \
# parent_minor_child                    ...
# count                                 ...
#
# age                                                                                                         11.0  \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               1
#
# age                                                     12.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    207
#
# age                                                     13.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    201
#
# age                                                     14.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    168
#
# age                                                     15.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    141
#
# age                                                     16.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    130
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               2
#
# age                                                     17.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    142
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               1
#
# age                                                     18.0
# parent_minor_child Not parent with minor child in the family
# count                                                      1
#
# [1 rows x 24 columns]

# %%
k = children.loc[children['parent_minor_child']=="Yes, a parent with a minor child in the family, but not used in two-parent participation rate",('case_number','age','parent_minor_child')]
k = pd.DataFrame(k)

l = children.loc[children['parent_minor_child']=="Yes, a parent with a minor child in the family and used in two-parent participation rate",('case_number','age','parent_minor_child')]
l = pd.DataFrame(l)

df1 = pd.concat([k,l],ignore_index=True)
df1
# Out:
#    case_number   age                                 parent_minor_child
# 0      6077810  17.0  Yes, a parent with a minor child in the family...
# 1      7863388  16.0  Yes, a parent with a minor child in the family...
# 2      9004467  16.0  Yes, a parent with a minor child in the family...
# 3      9029763  11.0  Yes, a parent with a minor child in the family...
# 4      9068090   1.0  Yes, a parent with a minor child in the family...

# %%
cn = df1['case_number'].nunique()
print(cn) #number of unique cases
print(df1.shape) #total number of parent with minor child instances
# Out:
# 5
# (5, 3)

# %%
children.groupby(['family_affiliation','age']).agg({'parent_minor_child':'value_counts'},axis='columns').rename({'parent_minor_child':'count'},axis='columns')#.reset_index()
# Out:
#                                                                                                              count
# family_affiliation                                 age   parent_minor_child
# Member of the eligible family receiving assistance  0.0  Not parent with minor child in the family             189
#                                                     1.0  Not parent with minor child in the family             255
#                                                          Yes, a parent with a minor child in the family,...      1
#                                                     2.0  Not parent with minor child in the family             274
#                                                     3.0  Not parent with minor child in the family             291
#                                                     4.0  Not parent with minor child in the family             259
#                                                     5.0  Not parent with minor child in the family             206
#                                                     6.0  Not parent with minor child in the family             235
#                                                     7.0  Not parent with minor child in the family             219
#                                                     8.0  Not parent with minor child in the family             198
#                                                     9.0  Not parent with minor child in the family             192
#                                                     10.0 Not parent with minor child in the family             185
#                                                     11.0 Not parent with minor child in the family             206
#                                                          Yes, a parent with a minor child in the family,...      1
#                                                     12.0 Not parent with minor child in the family             207
#                                                     13.0 Not parent with minor child in the family             201
#                                                     14.0 Not parent with minor child in the family             168
#                                                     15.0 Not parent with minor child in the family             141
#                                                     16.0 Not parent with minor child in the family             130
#                                                          Yes, a parent with a minor child in the family,...      2
#                                                     17.0 Not parent with minor child in the family             142
#                                                          Yes, a parent with a minor child in the family,...      1
#                                                     18.0 Not parent with minor child in the family               1
# Person whose income or resources are considered... -1.0  Not parent with minor child in the family               1
#                                                     0.0  Not parent with minor child in the family              32
#                                                     1.0  Not parent with minor child in the family              37
#                                                     2.0  Not parent with minor child in the family              39
#                                                     3.0  Not parent with minor child in the family              30
#                                                     4.0  Not parent with minor child in the family              26
#                                                     5.0  Not parent with minor child in the family              23

# %%
children['age'].describe()
# Out:
# count    3892.000000
# mean        7.367163
# std         5.026691
# min        -1.000000
# 25%         3.000000
# 50%         7.000000
# 75%        12.000000
# max        18.000000
# Name: age, dtype: float64

# %%
children.shape
# Out:
# (4076, 26)

# %%
os.chdir('H://Current_Working_Folder//Reports Analytics//202008')
import openpyxl

file_name = 'ParentWithMinorChild.xlsx'
writer = pd.ExcelWriter(file_name, engine = 'openpyxl')

if os.path.exists(file_name):
    book = openpyxl.load_workbook(file_name)
    writer.book = book
    
df1.to_excel(writer, sheet_name = '202008', index=False)
writer.save()
writer.close()

# %%
children.columns
# Out:
# Index(['id', 'reporting_month', 'case_number', 'family_affiliation', 'dob',
#        'ssn', 'hispanic or latino', 'american indian or alaska native',
#        'asian', 'black or african american',
#        'native hawaiian or other pacific islander', 'white', 'gender',
#        'Receives Benefits Based on Federal Disability Status Under Non-Social Security Act Programs',
#        'Receives Supplemental Security Income Under Title XVI-SSI of the SocialSecurity Act:',
#        'relation_to_hoh', 'parent_minor_child', 'education_level',
#        'citizenship', 'Amount of unearned inocme_SSI',
#        'Amount of unearned income_Other unearned income', 'created_by',
#        'updated_by', 'created_at', 'updated_at', 'age'],
#       dtype='object')
