# %%
import pandas as pd
import numpy as np
import os

# %%
children = adult = pd.read_excel('S://TANF Reports//Reports Analytics//202109//202109-t_worc_children-220201-1019.xlsx')

# %%
children['reporting_month'] = pd.to_datetime(children['reporting_month'].
                                             apply(lambda x: f"{x}01").
                                             astype(str), infer_datetime_format=True)

children['dob'] = pd.to_datetime(children['dob'].astype(str), infer_datetime_format=True)

children['age'] = np.floor((children['reporting_month'] - children['dob'])/np.timedelta64(1,'Y'))

# %%
children.shape
# Out:
# (2365, 26)

# %%
children['parent_minor_child'].value_counts()
# Out:
# Not parent with minor child in the family                                                        2364
# Yes, a parent with a minor child in the family, but not used in two-parent participation rate       1
# Name: parent_minor_child, dtype: int64

# %%
children.groupby(children['age']).agg({'parent_minor_child':'value_counts'}).rename({'parent_minor_child':'count'}, axis='columns').T
# Out:
# age                                                    -1.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                      1
#
# age                                                     0.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                     89
#
# age                                                     1.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    125
#
# age                                                     2.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    144
#
# age                                                     3.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    141
#
# age                                                     4.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    168
#
# age                                                     5.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    158
#
# age                                                     6.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    119
#
# age                                                     7.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    138
#
# age                                                     8.0   ...  \
# parent_minor_child Not parent with minor child in the family  ...
# count                                                    156  ...
#
# age                                                     10.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    131
#
# age                                                     11.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    112
#
# age                                                     12.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    145
#
# age                                                     13.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    150
#
# age                                                     14.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    143
#
# age                                                     15.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    128
#
# age                                                     16.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    102
#
# age                                                     17.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                     82
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               1
#
# age                                                     18.0
# parent_minor_child Not parent with minor child in the family
# count                                                      1
#
# [1 rows x 21 columns]

# %%
k = children.loc[children['parent_minor_child']=="Yes, a parent with a minor child in the family, but not used in two-parent participation rate",('case_number','age','parent_minor_child')]
k = pd.DataFrame(k)

l = children.loc[children['parent_minor_child']=="Yes, a parent with a minor child in the family and used in two-parent participation rate",('case_number','age','parent_minor_child')]
l = pd.DataFrame(l)

# Append dataframes one below the other using concat
df1 = pd.concat([k,l],ignore_index=True)
df1
# Out:
#    case_number   age                                 parent_minor_child
# 0      9004467  17.0  Yes, a parent with a minor child in the family...

# %%
cn = df1['case_number'].nunique()
print(cn) #number of unique cases
print(df1.shape) #total number of parent with minor child instances
# Out:
# 1
# (1, 3)

# %%
children.groupby(['family_affiliation','age']).agg({'parent_minor_child':'value_counts'},axis='columns').rename({'parent_minor_child':'count'},axis='columns')#.reset_index()
# Out:
#                                                                                                              count
# family_affiliation                                 age   parent_minor_child
# Member of the eligible family receiving assistance -1.0  Not parent with minor child in the family               1
#                                                     0.0  Not parent with minor child in the family              80
#                                                     1.0  Not parent with minor child in the family             108
#                                                     2.0  Not parent with minor child in the family             134
#                                                     3.0  Not parent with minor child in the family             128
#                                                     4.0  Not parent with minor child in the family             154
#                                                     5.0  Not parent with minor child in the family             148
#                                                     6.0  Not parent with minor child in the family             109
#                                                     7.0  Not parent with minor child in the family             128
#                                                     8.0  Not parent with minor child in the family             141
#                                                     9.0  Not parent with minor child in the family             122
#                                                     10.0 Not parent with minor child in the family             124
#                                                     11.0 Not parent with minor child in the family             105
#                                                     12.0 Not parent with minor child in the family             138
#                                                     13.0 Not parent with minor child in the family             144
#                                                     14.0 Not parent with minor child in the family             135
#                                                     15.0 Not parent with minor child in the family             124
#                                                     16.0 Not parent with minor child in the family              98
#                                                     17.0 Not parent with minor child in the family              70
#                                                          Yes, a parent with a minor child in the family,...      1
#                                                     18.0 Not parent with minor child in the family               1
# Person whose income or resources are considered...  0.0  Not parent with minor child in the family               9
#                                                     1.0  Not parent with minor child in the family              17
#                                                     2.0  Not parent with minor child in the family              10
#                                                     3.0  Not parent with minor child in the family              13
#                                                     4.0  Not parent with minor child in the family              14
#                                                     5.0  Not parent with minor child in the family              10
#                                                     6.0  Not parent with minor child in the family              10
#                                                     7.0  Not parent with minor child in the family              10
#                                                     8.0  Not parent with minor child in the family              15
#                                                     9.0  Not parent with minor child in the family               9
#                                                     10.0 Not parent with minor child in the family               7
#                                                     11.0 Not parent with minor child in the family               7
#                                                     12.0 Not parent with minor child in the family               7
#                                                     13.0 Not parent with minor child in the family               6
#                                                     14.0 Not parent with minor child in the family               8
#                                                     15.0 Not parent with minor child in the family               4
#                                                     16.0 Not parent with minor child in the family               4
#                                                     17.0 Not parent with minor child in the family              12

# %%
children['age'].describe()
# Out:
# count    2365.000000
# mean        8.295560
# std         4.937529
# min        -1.000000
# 25%         4.000000
# 50%         8.000000
# 75%        13.000000
# max        18.000000
# Name: age, dtype: float64

# %%
children.shape
# Out:
# (2365, 26)

# %%
os.chdir('S://TANF Reports//Reports Analytics//202109')

from pandas import ExcelWriter

file_name = 'ParentWithMinorChild.xlsx'

writer = pd.ExcelWriter(file_name)
df1.to_excel(writer, sheet_name = '202109', index=False)
writer.save()
writer.close()


"""
import openpyxl
writer = pd.ExcelWriter(file_name, engine = 'openpyxl')

if os.path.exists(file_name):
    book = openpyxl.load_workbook(file_name)
    writer.book = book
    
df1.to_excel(writer, sheet_name = '202103', index=False)
writer.save()
writer.close()
"""
# Out:
# C:\Users\nnagaraj\AppData\Roaming\Python\Python39\site-packages\xlsxwriter\workbook.py:338: UserWarning: Calling close() on already closed file.
#   warn("Calling close() on already closed file.")
# "\nimport openpyxl\nwriter = pd.ExcelWriter(file_name, engine = 'openpyxl')\n\nif os.path.exists(file_name):\n    book = openpyxl.load_workbook(file_name)\n    writer.book = book\n    \ndf1.to_excel(writer, sheet_name = '202103', index=False)\nwriter.save()\nwriter.close()\n"
