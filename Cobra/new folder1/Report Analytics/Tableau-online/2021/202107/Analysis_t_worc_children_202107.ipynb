# %%
import pandas as pd
import numpy as np
import os

# %%
children = adult = pd.read_excel('S://TANF Reports//Reports Analytics//202107//202107-t_worc_children-220102_839.xlsx')

# %%
children['reporting_month'] = pd.to_datetime(children['reporting_month'].
                                             apply(lambda x: f"{x}01").
                                             astype(str), infer_datetime_format=True)

children['dob'] = pd.to_datetime(children['dob'].astype(str), infer_datetime_format=True)

children['age'] = np.floor((children['reporting_month'] - children['dob'])/np.timedelta64(1,'Y'))

# %%
children.shape
# Out:
# (2508, 26)

# %%
children['parent_minor_child'].value_counts()
# Out:
# Not parent with minor child in the family                                                        2507
# Yes, a parent with a minor child in the family, but not used in two-parent participation rate       1
# Name: parent_minor_child, dtype: int64

# %%
children.groupby(children['age']).agg({'parent_minor_child':'value_counts'}).rename({'parent_minor_child':'count'}, axis='columns').T
# Out:
# age                                                    -1.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                      1
#
# age                                                     0.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                     94
#
# age                                                     1.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    151
#
# age                                                     2.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    180
#
# age                                                     3.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    168
#
# age                                                     4.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    166
#
# age                                                     5.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    164
#
# age                                                     6.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    133
#
# age                                                     7.0   \
# parent_minor_child Not parent with minor child in the family
# count                                                    167
#
# age                                                     8.0   ...  \
# parent_minor_child Not parent with minor child in the family  ...
# count                                                    150  ...
#
# age                                                     10.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    134
#
# age                                                     11.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    132
#
# age                                                     12.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    148
#
# age                                                     13.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    139
#
# age                                                     14.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    145
#
# age                                                     15.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    120
#
# age                                                     16.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                    100
#
# age                                                     17.0  \
# parent_minor_child Not parent with minor child in the family
# count                                                     79
#
# age                                                                                                               \
# parent_minor_child Yes, a parent with a minor child in the family, but not used in two-parent participation rate
# count                                                               1
#
# age                                                     18.0
# parent_minor_child Not parent with minor child in the family
# count                                                      1
#
# [1 rows x 21 columns]

# %%
k = children.loc[children['parent_minor_child']=="Yes, a parent with a minor child in the family, but not used in two-parent participation rate",('case_number','age','parent_minor_child')]
k = pd.DataFrame(k)

l = children.loc[children['parent_minor_child']=="Yes, a parent with a minor child in the family and used in two-parent participation rate",('case_number','age','parent_minor_child')]
l = pd.DataFrame(l)

# Append dataframes one below the other using concat
df1 = pd.concat([k,l],ignore_index=True)
df1
# Out:
#    case_number   age                                 parent_minor_child
# 0      9004467  17.0  Yes, a parent with a minor child in the family...

# %%
cn = df1['case_number'].nunique()
print(cn) #number of unique cases
print(df1.shape) #total number of parent with minor child instances
# Out:
# 1
# (1, 3)

# %%
children.groupby(['family_affiliation','age']).agg({'parent_minor_child':'value_counts'},axis='columns').rename({'parent_minor_child':'count'},axis='columns')#.reset_index()
# Out:
#                                                                                                              count
# family_affiliation                                 age   parent_minor_child
# Member of the eligible family receiving assistance -1.0  Not parent with minor child in the family               1
#                                                     0.0  Not parent with minor child in the family              93
#                                                     1.0  Not parent with minor child in the family             149
#                                                     2.0  Not parent with minor child in the family             174
#                                                     3.0  Not parent with minor child in the family             164
#                                                     4.0  Not parent with minor child in the family             164
#                                                     5.0  Not parent with minor child in the family             159
#                                                     6.0  Not parent with minor child in the family             124
#                                                     7.0  Not parent with minor child in the family             162
#                                                     8.0  Not parent with minor child in the family             145
#                                                     9.0  Not parent with minor child in the family             132
#                                                     10.0 Not parent with minor child in the family             130
#                                                     11.0 Not parent with minor child in the family             121
#                                                     12.0 Not parent with minor child in the family             146
#                                                     13.0 Not parent with minor child in the family             136
#                                                     14.0 Not parent with minor child in the family             144
#                                                     15.0 Not parent with minor child in the family             118
#                                                     16.0 Not parent with minor child in the family              99
#                                                     17.0 Not parent with minor child in the family              76
#                                                          Yes, a parent with a minor child in the family,...      1
#                                                     18.0 Not parent with minor child in the family               1
# Person whose income or resources are considered...  0.0  Not parent with minor child in the family               1
#                                                     1.0  Not parent with minor child in the family               2
#                                                     2.0  Not parent with minor child in the family               6
#                                                     3.0  Not parent with minor child in the family               4
#                                                     4.0  Not parent with minor child in the family               2
#                                                     5.0  Not parent with minor child in the family               5
#                                                     6.0  Not parent with minor child in the family               9
#                                                     7.0  Not parent with minor child in the family               5
#                                                     8.0  Not parent with minor child in the family               5
#                                                     9.0  Not parent with minor child in the family               3
#                                                     10.0 Not parent with minor child in the family               4
#                                                     11.0 Not parent with minor child in the family              11
#                                                     12.0 Not parent with minor child in the family               2
#                                                     13.0 Not parent with minor child in the family               3
#                                                     14.0 Not parent with minor child in the family               1
#                                                     15.0 Not parent with minor child in the family               2
#                                                     16.0 Not parent with minor child in the family               1
#                                                     17.0 Not parent with minor child in the family               3

# %%
children['age'].describe()
# Out:
# count    2508.000000
# mean        7.999601
# std         4.924196
# min        -1.000000
# 25%         4.000000
# 50%         8.000000
# 75%        12.000000
# max        18.000000
# Name: age, dtype: float64

# %%
children.shape
# Out:
# (2508, 26)

# %%
os.chdir('S://TANF Reports//Reports Analytics//202107')

from pandas import ExcelWriter

file_name = 'ParentWithMinorChild.xlsx'

writer = pd.ExcelWriter(file_name)
df1.to_excel(writer, sheet_name = '202107', index=False)
writer.save()
writer.close()


"""
import openpyxl
writer = pd.ExcelWriter(file_name, engine = 'openpyxl')

if os.path.exists(file_name):
    book = openpyxl.load_workbook(file_name)
    writer.book = book
    
df1.to_excel(writer, sheet_name = '202103', index=False)
writer.save()
writer.close()
"""
# Out:
# C:\Users\nnagaraj\AppData\Roaming\Python\Python39\site-packages\xlsxwriter\workbook.py:338: UserWarning: Calling close() on already closed file.
#   warn("Calling close() on already closed file.")
# "\nimport openpyxl\nwriter = pd.ExcelWriter(file_name, engine = 'openpyxl')\n\nif os.path.exists(file_name):\n    book = openpyxl.load_workbook(file_name)\n    writer.book = book\n    \ndf1.to_excel(writer, sheet_name = '202103', index=False)\nwriter.save()\nwriter.close()\n"
